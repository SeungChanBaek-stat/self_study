# %% [markdown]
# # **16기 운영진 코딩 테스트**
#
# 이 코딩 테스트는 총 100점 만점이며, 3개의 섹션으로 구성되어 있습니다.
# * 테스트를 시작하기 전에 하단 필요 패키지 를 먼저 실행하신 후 진행하시면 됩니다.
#
# ## **다음 2가지 사항을 반드시 준수해주세요.**
#
#
# 1. ipynb 파일 형식으로 저장 후 다음의 구글폼으로 제출 https://forms.gle/NUXTUNmSmCsQGM5U8
# 2. 파일명 마지막에 본인 이름 추가
# 예시 : 16기_운영진_코딩테스트_문제지_본인이름

# %% [markdown]
# ## **필요 패키지**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **1부 : python, numpy, pandas 기초 (20점)**

# %% [markdown]
# ### **문제 1.1 (3점)**
#
# 오늘의 날짜, 자신의 이름, 자신의 생일, MBTI를 리스트로 저장하고 그것을 Series 형태로 변환하여 출력하세요.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **문제 1.2 (4점)**
# 자연수 n이 주어졌을 때, n의 모든 약수를 찾아 합산하는 함수 sum_of_divisors(n)를 작성하세요.
#
# *  함수 안에 부분을 채워주세요

# %%
def sum_of_divisors(n):


print(sum_of_divisors(12))

# %% [markdown]
# ### **문제 1.3 (5점)**
#
#
# 딕셔너리를 활용하여 다음의 DataFrame을 출력하세요.
# * Dataframe은 **product_df**로 저장해주세요
# * NaN은 결측치입니다
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **문제 1.4 (2점)**
#
# 위에서 만들어진 product_df의 ***제품*** 열을 인덱스로 지정해주세요
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **문제 1.5 (3점)**
#
# ***가격***과 ***원가***의 결측치는 각각 **평균**으로 채우세요
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **문제 1.6 (3점)**
#
# 각 제품의 **이익률**을 계산하여 ***이익률(%)*** 이라는 컬럼으로 추가하세요.
#
# * **이익률 계산 공식:** ((가격 - 원가) / 원가) × 100
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2부 : 데이터 전처리 및 분석 (50점)**

# %%
# 코랩 사용자만 아래 마운트 코드 실행
# 이외의 경우 해당 코드 실행X
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## **문제 2.1 (4점)**

# %% [markdown]
# london_merged.csv 파일을 불러오고 london_df 변수에 저장하여 맨 위에 5개 행을 출력하세요.
#
# 출력예시: ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **문제 2.2 (5점)**

# %% [markdown]
# **timestamp**를 **datetime**으로 변환하고 ***year, month, hour, weekday*** 컬럼을 생성한 후 상위 5개 행을 출력하세요.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **문제 2.3 (6점)**

# %% [markdown]
# 평일,주말과 공휴일을 구분하는 새로운 변수 ***day_type (평일/주말/공휴일)*** 을 생성하시오. 이때 각각의 값은 아래 예시와 같이 **weekday,weekend,holiday**로 출력되게 하시오.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **문제 2.4 (5점)**

# %% [markdown]
# ***wind_speed*** 컬럼에 대해 **Min-Max 정규화**를 적용한 결과를
# ***wind_speed_norm***이라는 새로운 컬럼에 저장하세요.
#
# 이후, ***wind_speed***와 ***wind_speed_norm*** 두 컬럼만 포함된
# 데이터프레임을 출력하세요
#
# 출력 예시:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **문제 2.5 (8점)**

# %% [markdown]
# ***wind_speed*** 컬럼에 대해
# **IQR** 기준으로 이상치를 탐지하고 제거한 뒤,
# 이상치 제거 전과 후의 데이터 행 수 차이를 비교하세요.
#
# 출력 예시:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **문제 2.6 (5점)**

# %% [markdown]
# 시민들이 가장 많이 자전거를 빌리는 요일-시간 조합을 파악하려 합니다.
# **london_df**에서 ***weekday***와 ***hour***를 기준으로 그룹화하여
# **cnt의 평균**을 계산한 뒤,
# cnt량이 가장 많은 상위 10개 요일-시간 조합을 **top_10_usage**에 저장하고 출력하세요.
#
# 출력 예시:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **문제 2.7 (5점)**

# %% [markdown]
# **london_df**에서 ***t1, hum, cnt*** 간의
# **상관계수**를 계산하세요.

# %% [markdown]
# ## **문제 2.8 (6점)**

# %% [markdown]
# 계산된 상관계수 행렬을 **히트맵**으로 시각화하세요.
# 히트맵의 색상은 **coolwarm**으로 지정해주세요
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **문제 2.9 (6점)**
# london_df를 london_df.csv 라는 파일명의 csv로 저장해주세요. 이때, 출력 예시처럼 저장되어야 합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **3부 : 모델링** (30점)

# %% [markdown]
# ## **필요 패키지**

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score,roc_curve, auc

# %% [markdown]
# ## **문제 3.1 (3점)**

# %% [markdown]
# **UCI_Credit_Card.csv**파일을 불러온 후,
# 총 행(row) 수와 열(column) 수를 출력하세요

# %% [markdown]
# ## **문제 3.2 (5점)**

# %% [markdown]
# 본 데이터셋에서 신용카드 연체 여부를 예측하기 위해
# ***default.payment.next.month*** 컬럼을 **타겟 변수 y**로 설정하고,
# 예측에 필요 없는 **ID 컬럼과 타겟 컬럼**을 제외한 나머지를
# **입력 변수 X**로 설정하세요.
#
# 그 후, 전체 데이터를 학습용 80%,평가용 20% 으로 나누세요.
# 단, 타겟 클래스 간의 비율이 유지되도록
# **Stratified Split**을 적용해야 합니다.
# **random_state**는 42로 지정해주세요.

# %% [markdown]
# ## **문제 3.3 (8점)**

# %% [markdown]
# **RandomForestClassifie**r를 이용해 모델을 학습한 후,
# 테스트셋에 대해 **Accuracy**와 **F1-score**를 출력하세요.

# %% [markdown]
# ## **문제 3.4 (9점)**

# %% [markdown]
# 학습한 **RandomForestClassifier** 모델에서
# 각 피처의 중요도(feature_importances_)를 추출하세요.
#
# 그 중 중요도가 높은 상위 10개 피처를 기준으로
# **막대그래프**를 시각화하세요.
#
# 색상은 **viridis**로 지정해주세요.
#
# * **그래프 제목**: Top 10 Important Features (Random Forest)
# * **x축명**: Importance
# * **y축명**: Feature
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **문제 3.5 (5점)**

# %% [markdown]
# 테스트셋에 대해 **predict_proba**로 예측 확률을 구하고,
# 해당 확률을 기반으로 ROC Curve의 **AUC 값**을 계산하세요.

# %% [markdown]
# # **END**
# 수고하셨습니다.
# 다음 구글폼에 **.ipynb** 파일 형식으로 제출해주세요.
#  https://forms.gle/NUXTUNmSmCsQGM5U8
#
#
# </br>
#
#
# **좋은 결과 있으시길 바라며, 코딩테스트는 종합적인 평가 요소 중 하나일 뿐, 결정적인 요인이 아닙니다.**
